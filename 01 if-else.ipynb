# %%
# take the user input and check if its positive or negative

num = int(input("Enter the number "))

if num > 0:
    print("+ve")
elif num == 0:
    print("zero")
else:
    print("-ve")
# Out:
# Enter the number  0
# zero

# %%
num = int(input("Enter the number "))

if num % 2 == 0:
    print('even')
else:
    print("odd")
# Out:
# Enter the number  4
# even

# %%
# 2000   leap
# 2016   leap
# 2017    not leap
# 1800    not leap

# %%
yr = int(input("Enter the year "))

if yr % 4 == 0:
    if yr % 100 == 0:
        if yr % 400 == 0:
            print("leap century year")
        else:
            print("century but not leap")
    else:
        print("leap year")
else:
    print("not leap")
# Out:
# Enter the year  1800
# century but not leap

# %%
num = int(input("Enter the number "))

if num % 2 == 0:
    pass
# Out:
# Enter the number  6

# %%
print("Welcome to simple calc")

num = int(input("Enter the number "))

print("MENU=> \n1. Square\n2. Cube\n3. +ve or -ve")

ch = int(input("Enter the choice"))

if ch == 1:
    print(num * num)
elif ch == 2:
    print(num ** 3)
elif ch == 3:
    if num > 0:
        print("+ve")
    elif num == 0:
        print("zero")
    else:
        print("-ve")
else:
    print("please visit nearest eye clinic !!! ")
# Out:
# Welcome to simple calc
# Enter the number  6
# MENU=>
# 1. Square
# 2. Cube
# 3. +ve or -ve
# Enter the choice 98688588
# please visit nearest eye clinic !!!
