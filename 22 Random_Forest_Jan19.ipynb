# %%
# data => banknotes.csv
# location => https://mitu.co.in/dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('banknotes.csv')
df.head()
# Out:
#    Variance  Skewness  Curtosis  Entropy  Class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %%
"""  
check for missing values
check with scatter plot for patterns
correlation matrix using heatmap
distribution of target variable (countplot)
""";

# %%
df.isnull().sum()
# Out:
# Variance    0
# Skewness    0
# Curtosis    0
# Entropy     0
# Class       0
# dtype: int64

# %%
sns.pairplot(df, hue='Class');

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm');

# %%
sns.countplot(x='Class', data=df);

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    762
# 1    610
# Name: count, dtype: int64

# %%
# separate features and target variable
# do the cross validation with stratification on target variable and 75:25 split

# %%
x = df.drop('Class', axis=1)
y = df['Class']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, stratify=y, random_state=0)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((1029, 4), (343, 4), (1029,), (343,))

# %%
# build the model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=150, random_state=0)
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=150, random_state=0)

# %%
# evaluate the model

# %%
y_pred = rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay, classification_report

# %%
CM = ConfusionMatrixDisplay.from_predictions(y_test, y_pred);

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       191
#            1       0.98      1.00      0.99       152
#
#     accuracy                           0.99       343
#    macro avg       0.99      0.99      0.99       343
# weighted avg       0.99      0.99      0.99       343

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9912536443148688

# %%
rf.estimators_;

# %%
rf.feature_importances_
# Out:
# array([0.5533406 , 0.22416798, 0.16687999, 0.05561143])

# %%
x.columns
# Out:
# Index(['Variance', 'Skewness', 'Curtosis', 'Entropy'], dtype='object')

# %% [markdown]
# # Random Forest Regressor

# %%
""" 
data => petrol_consumption.csv
location => https://mitu.co.in/dataset

build the Random Forest Regression model and evaluate it.
""";

# %%
df = pd.read_csv('petrol_consumption.csv')
df.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# 4                 410

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm');

# %%
df.columns
# Out:
# Index(['Petrol_tax', 'Average_income', 'Paved_Highways',
#        'Population_Driver_licence(%)', 'Petrol_Consumption'],
#       dtype='object')

# %%
x = df.drop('Petrol_Consumption', axis = 1)
y = df['Petrol_Consumption']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor(n_estimators=100, random_state=0)
rfr.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
# evaluate the model

# %%
y_pred = rfr.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 59.69

# %%
r2_score(y_test, y_pred)
# Out:
# 0.1328226285118942
