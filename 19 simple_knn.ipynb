# %%
# data => ingredients.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('ingredients.csv')
df.head()
# Out:
#    sweetness  crunchiness ingredients    class
# 0          1            1      cheese  protein
# 1          3            1        fish  protein
# 2          2            2      shrimp  protein
# 3          1            4       bacon  protein
# 4          3            5        nuts  protein

# %%
df.columns
# Out:
# Index(['sweetness', 'crunchiness', 'ingredients', 'class'], dtype='object')

# %%
df.shape
# Out:
# (15, 4)

# %%
df.isna().sum()
# Out:
# sweetness      0
# crunchiness    0
# ingredients    0
# class          0
# dtype: int64

# %%
sns.jointplot(data = df, x = 'sweetness', y = 'crunchiness', hue = 'class');

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=4)

# %%
x = df[['sweetness', 'crunchiness']]
y = df['class']

# %%
knn.fit(x, y)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
# predict for following
sweetness = 6
crunchiness = 4

# %%
tomato = pd.DataFrame({'sweetness': [sweetness], 'crunchiness': [crunchiness]})

# %%
tomato
# Out:
#    sweetness  crunchiness
# 0          6            4

# %%
knn.predict(tomato)
# Out:
# array(['fruit'], dtype=object)
