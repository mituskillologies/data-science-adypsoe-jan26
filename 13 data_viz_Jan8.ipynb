# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.array([12, 23, 34, 37, 40, 44, 52, 57, 68, 72])
y = np.array([15, 22, 33, 35, 45, 43, 50, 60, 65, 70])
z = np.array([71, 66, 59, 54, 48, 42, 38, 33, 25, 20])

# %% [markdown]
# # line chart

# %%
plt.xlabel('x values')
plt.ylabel('y values')
plt.title("line chart")
plt.plot(x, y, marker = 'o', mfc = 'orange', ls = '--');
plt.grid();

# %%
plt.xlabel('x values')
plt.ylabel('y values')
plt.title("line chart")
plt.plot(x, z, marker = 'o', mfc = 'orange', ls = '--');
plt.grid();

# %%
plt.xlabel('x values')
plt.ylabel('y values')
plt.title("line chart")
plt.plot(x, y, marker = 'o', mfc = 'orange', ls = '--',
         label = "rice");
plt.plot(x, z, marker = 'o', mfc ="" 'blue', ls = '--',
         color = 'black', label = "sugar");
plt.grid();
plt.legend();

# %%
courses = ['DSA', 'Web Dev', 'Data Science', 'Machine Learning', 'AI']
enrollment = [120, 150, 100, 80, 70]

# %%
plt.bar(courses, enrollment, color = 'purple');
plt.xticks(rotation = 45);

# %%
df = pd.read_csv('student.csv')
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
plt.bar(df['name'], df['marks'], color = 'green');
plt.xticks(rotation = 45);

# %%
plt.figure(figsize = (10, 6))

plt.subplot(2, 2, 2)
plt.xlabel('x values')
plt.ylabel('y values')
plt.title("line chart")
plt.plot(x, y, marker = 'o', mfc = 'orange', ls = '--');
plt.grid();

plt.subplot(2, 2, 1)
plt.xlabel('x values')
plt.ylabel('y values')
plt.title("line chart")
plt.plot(x, z, marker = 'o', mfc = 'orange', ls = '--');
plt.grid();

# %%
# Scatter chart

# %%
plt.scatter(x, y, marker = 'o', color = 'red');

# %%
# Social_Network_Ads.csv
# location => https://mitu.co.in/dataset

# %%
df1 = pd.read_csv('Social_Network_Ads.csv')
df1.shape
# Out:
# (400, 5)

# %%
df1
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
plt.scatter(df1['Age'], df1['EstimatedSalary'], marker = 'o', c = df1['Purchased'], cmap = 'bwr');

# %%
df1['Purchased'].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
# pie chart

# %%
plt.pie(enrollment, labels = courses, autopct = '%.2f%%',
        explode= [0, 0.2, 0, 0, 0], shadow = True);

# %%
"""  
from social_network_ads.csv dataset
plot a pie chart to show how many users purchased the product vs how many did not purchase the product
""";

# %%
plt.pie(df1['Purchased'].value_counts(), labels = df1['Purchased'].value_counts().index, autopct = '%1.1f%%', colors = ['cyan', 'green']);

# %%
marks = [65, 68, 85, 60, 67, 65, 70, 63, 67]

# %%
np.mean(marks)
# Out:
# np.float64(67.77777777777777)

# %%
marks = [65, 68, 65, 60, 67, 65, 70, 63, 67, 92, 30]

# %%
plt.boxplot(marks);

# %%
# Seaborn

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue = 'species');

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(tips);
